# %%
#program to perform string operations
t=input("Enter a string")
s=input("Enter another string")
print("Print a string =",t)
print("Concatenated string=",t+ " "+s)
print("Length of string is=",len(t))
print ("Convert into uppercase=",t.upper())
# Out:
# Enter a string jasna
# Enter another string vazhayil
# Print a string = jasna
# Concatenated string= jasna vazhayil
# Python
# Length of string is= 5
# Convert into uppercase= JASNA

# %%
string="i am jasna"
print(string.replace("jasna","anu"))
# Out:
# i am anu

# %%
name="Jasna"
city="calicut"
print("My nameis {} and i am coming from {}".format(name,city))
# Out:
# My nameis Jasna and i am coming from calicut

# %%
text="Python"
print(text.ljust(20))
print(text.rjust(20))
print(text.center(20))
# Out:
# Python
#               Python
#        Python

# %%
word="   Hi world   "
print(word.strip())
# Out:
# Hi world

# %%
a=int(input("Enter a number:"))
b=int(input("Enter another number"))
print(a>b)
print(a<b)
print(a==b)
print(a!=b)
# Out:
# Enter a number: 4
# Enter another number 5
# False
# True
# False
# True

# %%
age=int(input("Enter age"))
if age>=18:
    print("eligble to vote")
else:
    print("not eligible to vote")
# Out:
# Enter age 23
# eligble to vote

# %%
color=input("enter different colors")
list=list(color.split("."))
print(list)
print("last color:",list[-1])
print("first color:",list[0])
# Out:
# enter different colors red green blue
# ['red green blue']
# last color: red green blue
# first color: red green blue

# %%
num=int(input("enter any range"))
for i in range(num):
    print(i)
# Out:
# enter any range 6
# 0
# 1
# 2
# 3
# 4
# 5

# %%
#program to get largest number from a list
numbers = list(map(int, input("Enter numbers: ").split()))
print("Largest number is:", max(numbers))
# Out:
# Enter numbers:  4 5 3
# Largest number is: 5

# %%
#program to remove duplicate from a list
numbers=[1,2,2,3,4,4,5]
unique_numbers=list(set(numbers))
print("List after removing duplicates:",unique_numbers)
# Out:
# List after removing duplicates: [1, 2, 3, 4, 5]

# %%
#tuple of key value pairs
t=(("a",1),("b",2),("c",3))
d={}
for key,value in t:
    d[key]=value
    print("Dictionary",d)
# Out:
# Dictionary {'a': 1}
# Dictionary {'a': 1, 'b': 2}
# Dictionary {'a': 1, 'b': 2, 'c': 3}

# %%
#program to merge 2 python dictionary
t={"apple":4,"kiwi":5}
s={"pen":5,"pencil":2}
merge=t|s
print ("merged dictionary:",merge)
# Out:
# merged dictionary: {'apple': 4, 'kiwi': 5, 'pen': 5, 'pencil': 2}

# %%
#program to write a function that takes 2 lists and return true if they have at least one common member

def common_number(list1,list2):
    for item in list1:
        if item in list2:
            return True
    return False
list1=[1,2,3,4]
list2=[5,6,3,8]
print (common(list1,list2))
# Out:
# True
